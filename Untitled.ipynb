# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('data.csv')
df
# Out:
#         Pet ID  Outcome Type Sex upon Outcome        Name  \
# 0      A794011           1.0    Neutered Male       Chunk
# 1      A776359           1.0    Neutered Male       Gizmo
# 2      A674754           0.0      Intact Male         NaN
# 3      A689724           1.0    Neutered Male  *Donatello
# 4      A680969           1.0    Neutered Male       *Zeus
# ...        ...           ...              ...         ...
# 95480  A811886           1.0    Neutered Male        Kane
# 95481  A817331           1.0    Spayed Female   *Squanchy
# 95482  A818067           1.0      Intact Male       Bluto
# 95483  A815418           0.0    Intact Female     Laverne
# 95484  A815419           0.0    Intact Female     Shirley
#
#                               Found Location      Intake Type  \
# 0                                Austin (TX)  Owner Surrender
# 1          7201 Levander Loop in Austin (TX)            Stray
# 2              12034 Research in Austin (TX)            Stray
# 3           2300 Waterway Bnd in Austin (TX)            Stray
# 4        4701 Staggerbrush Rd in Austin (TX)            Stray
# ...                                      ...              ...
# 95480                      Pflugerville (TX)  Owner Surrender
# 95481   1601 E Slaughter Lane in Austin (TX)    Public Assist
# 95482                            Austin (TX)  Owner Surrender
# 95483  2211 Santa Rita Street in Austin (TX)            Stray
# 95484  2211 Santa Rita Street in Austin (TX)            Stray
#
#       Intake Condition Pet Type Sex upon Intake  \
# 0               Normal      Cat   Neutered Male
# 1               Normal      Dog     Intact Male
# 2              Nursing      Cat     Intact Male
# 3               Normal      Cat     Intact Male
# 4              Nursing      Cat     Intact Male
# ...                ...      ...             ...
# 95480           Normal      Dog   Neutered Male
# 95481           Normal      Cat   Intact Female
# 95482           Normal      Dog     Intact Male
# 95483           Normal      Dog   Intact Female
# 95484           Normal      Dog   Intact Female
#
#                                     Breed               Color  \
# 0                  Domestic Shorthair Mix   Brown Tabby/White
# 1                 Chihuahua Shorthair Mix         White/Brown
# 2                  Domestic Shorthair Mix        Orange Tabby
# 3                  Domestic Shorthair Mix               Black
# 4                  Domestic Shorthair Mix  White/Orange Tabby
# ...                                   ...                 ...
# 95480  American Staffordshire Terrier Mix          Blue/White
# 95481                  Domestic Shorthair        Calico/White
# 95482                        Pit Bull Mix          Blue/White
# 95483                 Chihuahua Shorthair           Tan/White
# 95484                  Chihuahua Longhair                 Tan
#
#        Age upon Intake Days  Age upon Outcome Days
# 0                       730                    730
# 1                       365                    365
# 2                         6                      6
# 3                        60                     60
# 4                         7                     60
# ...                     ...                    ...
# 95480                  1095                   1095
# 95481                     7                     60
# 95482                  4745                   4745
# 95483                   365                    365
# 95484                   365                    365
#
# [95485 rows x 13 columns]

# %%
df.isnull()
# Out:
#        Pet ID  Outcome Type  Sex upon Outcome   Name  Found Location  \
# 0       False         False             False  False           False
# 1       False         False             False  False           False
# 2       False         False             False   True           False
# 3       False         False             False  False           False
# 4       False         False             False  False           False
# ...       ...           ...               ...    ...             ...
# 95480   False         False             False  False           False
# 95481   False         False             False  False           False
# 95482   False         False             False  False           False
# 95483   False         False             False  False           False
# 95484   False         False             False  False           False
#
#        Intake Type  Intake Condition  Pet Type  Sex upon Intake  Breed  Color  \
# 0            False             False     False            False  False  False
# 1            False             False     False            False  False  False
# 2            False             False     False            False  False  False
# 3            False             False     False            False  False  False
# 4            False             False     False            False  False  False
# ...            ...               ...       ...              ...    ...    ...
# 95480        False             False     False            False  False  False
# 95481        False             False     False            False  False  False
# 95482        False             False     False            False  False  False
# 95483        False             False     False            False  False  False
# 95484        False             False     False            False  False  False
#
#        Age upon Intake Days  Age upon Outcome Days
# 0                     False                  False
# 1                     False                  False
# 2                     False                  False
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 95480                 False                  False
# 95481                 False                  False
# 95482                 False                  False
# 95483                 False                  False
# 95484                 False                  False
#
# [95485 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95485 entries, 0 to 95484
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Pet ID                 95485 non-null  object
#  1   Outcome Type           95485 non-null  float64
#  2   Sex upon Outcome       95484 non-null  object
#  3   Name                   59138 non-null  object
#  4   Found Location         95485 non-null  object
#  5   Intake Type            95485 non-null  object
#  6   Intake Condition       95485 non-null  object
#  7   Pet Type               95485 non-null  object
#  8   Sex upon Intake        95484 non-null  object
#  9   Breed                  95485 non-null  object
#  10  Color                  95485 non-null  object
#  11  Age upon Intake Days   95485 non-null  int64
#  12  Age upon Outcome Days  95485 non-null  int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 9.5+ MB

# %%
df.describe()
# Out:
#        Outcome Type  Age upon Intake Days  Age upon Outcome Days
# count  95485.000000          95485.000000           95485.000000
# mean       0.564005            703.436959             717.757313
# std        0.495889           1052.252197            1055.023160
# min        0.000000              0.000000               0.000000
# 25%        0.000000             30.000000              60.000000
# 50%        1.000000            365.000000             365.000000
# 75%        1.000000            730.000000             730.000000
# max        1.000000           9125.000000            9125.000000

# %%
print(df.columns)
# Out:
# Index(['Pet ID', 'Outcome Type', 'Sex upon Outcome', 'Name', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Pet Type', 'Sex upon Intake',
#        'Breed', 'Color', 'Age upon Intake Days', 'Age upon Outcome Days'],
#       dtype='object')

# %%
model_features=df.columns.drop('Outcome Type')
model_target='Outcome Type'

# %%
numericals=df[model_features].select_dtypes(include=np.number).columns
print(numericals)
categoricals=df[model_features].select_dtypes(include='object').columns
print(categoricals)
# Out:
# Index(['Age upon Intake Days', 'Age upon Outcome Days'], dtype='object')
# Index(['Pet ID', 'Sex upon Outcome', 'Name', 'Found Location', 'Intake Type',
#        'Intake Condition', 'Pet Type', 'Sex upon Intake', 'Breed', 'Color'],
#       dtype='object')

# %%
df[model_target].value_counts()
# Out:
# 1.0    53854
# 0.0    41631
# Name: Outcome Type, dtype: int64

# %%
df[model_target].value_counts().plot.bar()
plt.show()

# %%
for c in model_features:
    print(df[c].value_counts())
# Out:
# A715382    1
# A764844    1
# A695411    1
# A697127    1
# A771615    1
#           ..
# A702916    1
# A773704    1
# A737356    1
# A666220    1
# A798307    1
# Name: Pet ID, Length: 95485, dtype: int64
# Neutered Male    30244
# Spayed Female    28145
# Intact Female    13724
# Intact Male      13646
# Unknown           9725
# Name: Sex upon Outcome, dtype: int64
# Bella          338
# Luna           313
# Max            311
# Daisy          239
# Lucy           223
#               ...
# Burt             1
# *Buckthorn       1
# Yola             1
# Magoo            1
# Sc-072618-5      1
# Name: Name, Length: 17468, dtype: int64
# Austin (TX)                                    14833
# Travis (TX)                                     1402
# 7201 Levander Loop in Austin (TX)                644
# Outside Jurisdiction                             607
# Del Valle (TX)                                   426
#                                                ...
# 1306 Conney Creek Dr in Austin (TX)                1
# Applegate Dr E & Newport Ave in Austin (TX)        1
# 2924 Bond Drive in Austin (TX)                     1
# West William Cannon in Austin (TX)                 1
# 8417 Red Willow Dr in Austin (TX)                  1
# Name: Found Location, Length: 43951, dtype: int64
# Stray                 70203
# Owner Surrender       15146
# Public Assist          5236
# Wildlife               4554
# Euthanasia Request      235
# Abandoned               111
# Name: Intake Type, dtype: int64
# Normal      81912
# Injured      5386
# Sick         4291
# Nursing      3172
# Aged          352
# Other         189
# Feral          97
# Pregnant       63
# Medical        21
# Behavior        2
# Name: Intake Condition, dtype: int64
# Dog          48719
# Cat          40082
# Other         6115
# Bird           553
# Livestock       16
# Name: Pet Type, dtype: int64
# Intact Male      33369
# Intact Female    32515
# Neutered Male    10521
# Unknown           9725
# Spayed Female     9354
# Name: Sex upon Intake, dtype: int64
# Domestic Shorthair Mix                   27689
# Domestic Shorthair                        5076
# Pit Bull Mix                              5017
# Chihuahua Shorthair Mix                   4963
# Labrador Retriever Mix                    4789
#                                          ...
# Frog                                         1
# Miniature Pinscher/Smooth Fox Terrier        1
# Leonberger/German Shepherd                   1
# Chinese Sharpei/Chow Chow                    1
# Toy Poodle/Chihuahua Shorthair               1
# Name: Breed, Length: 2395, dtype: int64
# Black/White              9688
# Black                    8528
# Brown Tabby              6077
# Brown                    4440
# White                    3312
#                          ...
# Blue Tabby/Tan              1
# Red Merle/Brown Merle       1
# Orange Tabby/Apricot        1
# Tan/Brown Merle             1
# Red/Brown Brindle           1
# Name: Color, Length: 567, dtype: int64
# 365     16162
# 730     13410
# 30      10548
# 60       5496
# 1095     4990
# 28       4076
# 21       3380
# 1460     2891
# 1825     2766
# 90       2608
# 120      2533
# 150      2460
# 14       2379
# 180      1872
# 2190     1846
# 7        1797
# 2920     1628
# 2555     1625
# 3650     1441
# 270      1347
# 210      1329
# 240      1063
# 3285      929
# 4380      713
# 0         703
# 300       599
# 1         578
# 3         524
# 4015      521
# 330       464
# 2         449
# 4745      435
# 5110      315
# 4         304
# 35        294
# 6         286
# 5475      281
# 5         174
# 5840      116
# 6205       67
# 6570       40
# 6935       23
# 7300       16
# 8030        4
# 7665        1
# 9125        1
# 8760        1
# Name: Age upon Intake Days, dtype: int64
# 365     16370
# 730     13434
# 60      12821
# 1095     5056
# 90       4910
# 30       4895
# 120      3199
# 1460     2850
# 1825     2793
# 150      2404
# 180      2385
# 21       2053
# 14       1965
# 2190     1841
# 28       1744
# 2920     1702
# 2555     1624
# 3650     1480
# 7        1457
# 240      1444
# 300      1263
# 210      1133
# 270       902
# 3285      898
# 4380      739
# 4015      524
# 330       462
# 4745      457
# 3         340
# 2         334
# 5110      321
# 5475      283
# 1         243
# 6         231
# 4         214
# 0         172
# 5         155
# 5840      118
# 35        112
# 6205       69
# 6570       42
# 6935       23
# 7300       16
# 8030        4
# 8760        1
# 9125        1
# 7665        1
# Name: Age upon Outcome Days, dtype: int64

# %%
df.isna().sum()
# Out:
# Pet ID                       0
# Outcome Type                 0
# Sex upon Outcome             1
# Name                     36347
# Found Location               0
# Intake Type                  0
# Intake Condition             0
# Pet Type                     0
# Sex upon Intake              1
# Breed                        0
# Color                        0
# Age upon Intake Days         0
# Age upon Outcome Days        0
# dtype: int64

# %%
threshold = 2/10
print((df.isna().sum()/len(df.index)))
columns_to_drop = df.loc[:,list(((df.isna().sum()/len(df.index))>=threshold))].columns    
print(columns_to_drop)

df_columns_dropped = df.drop(columns_to_drop, axis = 1)  
df_columns_dropped.head()
# Out:
# Pet ID                   0.000000
# Outcome Type             0.000000
# Sex upon Outcome         0.000010
# Name                     0.380657
# Found Location           0.000000
# Intake Type              0.000000
# Intake Condition         0.000000
# Pet Type                 0.000000
# Sex upon Intake          0.000010
# Breed                    0.000000
# Color                    0.000000
# Age upon Intake Days     0.000000
# Age upon Outcome Days    0.000000
# dtype: float64
# Index(['Name'], dtype='object')
#     Pet ID  Outcome Type Sex upon Outcome  \
# 0  A794011           1.0    Neutered Male
# 1  A776359           1.0    Neutered Male
# 2  A674754           0.0      Intact Male
# 3  A689724           1.0    Neutered Male
# 4  A680969           1.0    Neutered Male
#
#                         Found Location      Intake Type Intake Condition  \
# 0                          Austin (TX)  Owner Surrender           Normal
# 1    7201 Levander Loop in Austin (TX)            Stray           Normal
# 2        12034 Research in Austin (TX)            Stray          Nursing
# 3     2300 Waterway Bnd in Austin (TX)            Stray           Normal
# 4  4701 Staggerbrush Rd in Austin (TX)            Stray          Nursing
#
#   Pet Type Sex upon Intake                    Breed               Color  \
# 0      Cat   Neutered Male   Domestic Shorthair Mix   Brown Tabby/White
# 1      Dog     Intact Male  Chihuahua Shorthair Mix         White/Brown
# 2      Cat     Intact Male   Domestic Shorthair Mix        Orange Tabby
# 3      Cat     Intact Male   Domestic Shorthair Mix               Black
# 4      Cat     Intact Male   Domestic Shorthair Mix  White/Orange Tabby
#
#    Age upon Intake Days  Age upon Outcome Days
# 0                   730                    730
# 1                   365                    365
# 2                     6                      6
# 3                    60                     60
# 4                     7                     60
